# %% [markdown]
# Q3 Plots

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]
import pandas as pd

# %%
EVQ1 = pd.read_csv('C:/Users/Vincent/Documents/2022/SHPC4001/Assignment 5/EVQ1.csv', delim_whitespace=True, header=None)
EVQ1.rename(columns={0: 'Ev', 1: 'n'}, inplace=True)

plt.rcParams['figure.figsize'] = [10, 5]
fig, axs = plt.subplots(1)


axs.plot(EVQ1['n'], np.abs(EVQ1['Ev'][9]-EVQ1['Ev']), 'o', color = 'red')
axs.set_title('Figure 1.01:  Error of Calculateed Eigen Values')
axs.set_ylabel('Abs Error of Eigen Value')
axs.set_yscale('log')
axs.set_xlabel('Iterations')
# Out:
# Text(0.5, 0, 'Iterations')

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# %matplotlib inline

fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(111, projection='3d')


x = np.arange(-5,5,0.2)
y = np.arange(-5,5,0.2)
X,Y = np.meshgrid(x,y)
Z = 0.5*(X**2 + Y**2)


mycmap = plt.get_cmap('gnuplot')
ax1.set_title('Figure 3.03: Potential Funtion of QHO')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('V(x, y)')
surf1 = ax1.plot_surface(X, Y, Z, cmap=mycmap)
fig.colorbar(surf1, ax=ax1, shrink=0.5, aspect=10)


plt.show()

# %%
EV = pd.read_csv('C:/Users/Vincent/Documents/2022/SHPC4001/Assignment 5/ev20.csv', delim_whitespace=True, header=None)
EV.rename(columns={0: 'k', 1: 'p', 2:'Ev', 3:'Per' }, inplace=True)

plt.rcParams['figure.figsize'] = [10, 10]
fig, axs = plt.subplots(2)


axs[0].plot(EV['k'][0:10]-1, EV['Ev'][0:10], 'o', color = 'green')
axs[0].plot(EV['k'][0:10]-1, EV['k'][0:10], 'x', color = 'red')
axs[0].set_title('Figure 3.01:  EigenValues and Energy Levels')
axs[0].set_xlabel('Energy Level')
axs[0].set_ylabel('Relative Energy')
axs[0].legend(['Computed Eigenvalue','Theorectical Energy'])

axs[1].plot(EV['k'][0:10]-1, 100-EV['Per'][0:10],'o', color = 'blue')
axs[1].set_title('Figure 3.02: Absolute Error of Computed Value')
axs[1].set_xlabel('Energy Level')
axs[1].set_ylabel('Relative Error of Computed Value')
# Out:
# Text(0, 0.5, 'Relative Error of Computed Value')

# %% [markdown]
# Q1.6

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# %matplotlib inline

Ezero = pd.read_csv('C:/Users/Vincent/Documents/2022/SHPC4001/Assignment 5/Ezero.csv', delim_whitespace=True, header=None)
#EV.rename(columns={0: 'k', 1: 'p', 2:'Ev', 3:'Per' }, inplace=True)

fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(111, projection='3d')


x = np.arange(-4.8,5,0.2)
y = np.arange(-4.8,5,0.2)
X,Y = np.meshgrid(x,y)
Z = Ezero

mycmap = plt.get_cmap('gnuplot')
ax1.set_title('Figure 3.04: Computed Groundstate of QHO')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('E')
surf1 = ax1.plot_surface(X, Y, Z, cmap=mycmap)
fig.colorbar(surf1, ax=ax1, shrink=0.5, aspect=10)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# %matplotlib inline

fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(111, projection='3d')

x = np.arange(-4.8,5,0.2)
y = np.arange(-4.8,5,0.2)
X,Y = np.meshgrid(x,y)
Z = np.exp(-(X**2 + Y**2)/2)/(2*np.pi)

mycmap = plt.get_cmap('viridis')
ax1.set_title('Figure 3.05: Analytical Groundstate of QHO')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('E')
surf1 = ax1.plot_surface(X, Y, Z, cmap=mycmap)
fig.colorbar(surf1, ax=ax1, shrink=0.5, aspect=10)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# %matplotlib inline

fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(111, projection='3d')

x = np.arange(-4.8,5,0.2)
y = np.arange(-4.8,5,0.2)
X,Y = np.meshgrid(x,y)
Z = np.exp(-(X**2 + Y**2)/2)/(2*np.pi) - Ezero

mycmap = plt.get_cmap('viridis')
ax1.set_title('Figure 3.06: Absolute Error of Computee QHO Groundstate')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('Error(E)')
surf1 = ax1.plot_surface(X, Y, Z, cmap=mycmap)
fig.colorbar(surf1, ax=ax1, shrink=0.5, aspect=10)

plt.show()

# %%
max(Z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-c6f90058f798> in <module>
# ----> 1 max(Z)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
